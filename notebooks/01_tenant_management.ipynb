# %%
#Tenant Management Notebook
import pandas as pd
from sqlalchemy import select
from src.database import SessionLocal
from src.models import Tenant

# %%
sample_tenants = pd.DataFrame(
    [
        {
            "full_name": "Bennet Dyani",
            "email": "bennet@gmail.com",
            "phone": "+27630632730",
            "unit_number": "A1",
            "lease_start_date": "2026-02-01",
            "lease_end_date": "2021-01-30",
            "notes": "Preferes email communication"

        },
        {
            "full_name": "Itumeleng Bedesho",
            "email": "itumeleng@gmail.com",
            "phone": "+27678238210",
            "unit_number": "B2",
            "lease_start_date": "2026-07-01",
            "lease_end_date": "2027-06-30",
            "notes": "Has recuring maintenance request"

        }
    ]
)

sample_tenants
# Out:
#            full_name                email         phone unit_number  \
# 0       Bennet Dyani     bennet@gmail.com  +27630632730          A1
# 1  Itumeleng Bedesho  itumeleng@gmail.com  +27678238210          B2
#
#   lease_start_date lease_end_date                             notes
# 0       2026-02-01     2021-01-30      Preferes email communication
# 1       2026-07-01     2027-06-30  Has recuring maintenance request

# %%
#Tenant helper
from sqlalchemy import select

def list_tenants():
    with SessionLocal() as session:
        return session.scalar(select(Tenant)).all()

def add_tenant(full_name, email=None, phone=None, unit_number=None, lease_start_date=None, lease_end_date=None, notes=None):
    tenant = Tenant(
        full_name=full_name,
        email=email,
        phone=phone,
        unit_number=unit_number,
        lease_start_date=lease_start_date,
        lease_end_date=lease_end_date,
        notes=notes
    )

    with SessionLocal() as session:
        session.add(tenant)
        session.commit()
        session.refresh(tenant)

    return tenant

# %%
#Tenant lookup

def get_tenant_by_id(tenant_id):
    with SessionLocal() as session:
        return session.get(Tenant, tenant_id)

def get_tenant_by_email(email):
    with SessionLocal() as session:
        return session.scalar(select(Tenant).where(Tenant.email == email))

def get_tenant_by_phone(phone):
    with SessionLocal() as session:
        return session.scalar(select(Tenant).where(Tenant.phone == phone))

def get_tenant_by_unit(unit_number):
    with SessionLocal() as session:
        return session.scalar(select(Tenant).where(Tenant.unit_number == unit_number))

# %%
#Basic tenant Q&A

def tenant_qa(query, tenant_id=None, email=None, phone= None, unit_number=None):
    """
    Sample tenant Q&A function:
    Find a tenant and answer basic questions about them.
    """
    tenant = None
    if tenant_id:
        tenant = get_tenant_by_id(tenant_id)
    elif email:
        tenant = get_tenant_by_email(email)
    elif phone:
        tenant = get_tenant_by_phone(phone)
    elif unit_number:
        tenant = get_tenant_by_unit(unit_number)

    if not tenant:
        return "Tenant not found"

    query_lower = query.lower()

    if "name" in query_lower:
        return f"Tenant name: {tenant.full_name}"
    elif "email" in query_lower:
        return f"Email: {tenant.email}"
    elif "phone" in query_lower:
        return f"Phone: {tenant.phone}"
    elif "unit" in query_lower:
        return f"Unit: {tenant.unit_number}"
    elif "lease" in query_lower:
        return f"Lease: {tenant.lease_start_date} to {tenant.lease_end_date}"
    elif "notes" in query_lower:
        return f"Notes: {tenant.notes}"
    else:
        return f"Tenant info: {tenant.full_name}, Unit {tenant.unit_number}, Email: {tenant.email}"

# %%
# Insert sample tenants
tenant1 = add_tenant(
    full_name="Bennet Dyani",
    email="dyani@gmail.com",
    phone="+27809682354",
    unit_number="A1",
    lease_start_date="2026-01-01",
    lease_end_date="2026-12-31",
    notes="Prefers email communication",
)

tenant2 = add_tenant(
    full_name="Itumeleng Bedesho",
    email="bedesho@gmailcom",
    phone="+27633981147",
    unit_number="B3",
    lease_start_date="2026-02-01",
    lease_end_date="2027-01-31",
    notes="Has recurring maintenance request history",
)

print("Sample tenants added:")
print(f"Tenant 1: {tenant1.full_name} (ID: {tenant1.id})")
print(f"Tenant 2: {tenant2.full_name} (ID: {tenant2.id})")

# Test Q&A
print("\n--- Testing Q&A ---")
print(tenant_qa("What is the tenant's name?", tenant_id=tenant1.id))
#print(tenant_qa("What's their email?", email="brian@example.com"))
#print(tenant_qa("What unit?", phone="+254700000001"))
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\psycopg\cursor.py:117, in Cursor.execute(self, query, params, prepare, binary)
#     116 except e._NO_TRACEBACK as ex:
# --> 117     raise ex.with_traceback(None)
#     118 return self
#
# UndefinedTable: relation "tenants" does not exist
# LINE 1: INSERT INTO tenants (full_name, email, phone, unit_number, l...
#                     ^
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Insert sample tenants
# ----> 2 tenant1 = add_tenant(
#       3     full_name="Bennet Dyani",
#       4     email="dyani@gmail.com",
#       5     phone="+27809682354",
#
# Cell In[3], line 21, in add_tenant(full_name, email, phone, unit_number, lease_start_date, lease_end_date, notes)
#      17     )
#      18
#      19     with SessionLocal() as session:
#      20         session.add(tenant)
# ---> 21         session.commit()
#      22         session.refresh(tenant)
#      23
#      24     return tenant
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\session.py:2035, in Session.commit(self)
#    2032 if trans is None:
#    2033     trans = self._autobegin_t()
# -> 2035 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     135 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#     139     raise
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\session.py:1316, in SessionTransaction.commit(self, _to_root)
#    1314 if self._state is not SessionTransactionState.PREPARED:
#    1315     with self._expect_state(SessionTransactionState.PREPARED):
# -> 1316         self._prepare_impl()
#    1318 if self._parent is None or self.nested:
#    1319     for conn, trans, should_commit, autoclose in set(
#    1320         self._connections.values()
#    1321     ):
#
# File <string>:2, in _prepare_impl(self)
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     135 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#     139     raise
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\session.py:1290, in SessionTransaction._prepare_impl(self)
#    1288     if self.session._is_clean():
#    1289         break
# -> 1290     self.session.flush()
#    1291 else:
#    1292     raise exc.FlushError(
#    1293         "Over 100 subsequent flushes have occurred within "
#    1294         "session.commit() - is an after_flush() hook "
#    1295         "creating new objects?"
#    1296     )
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\session.py:4353, in Session.flush(self, objects)
#    4351 try:
#    4352     self._flushing = True
# -> 4353     self._flush(objects)
#    4354 finally:
#    4355     self._flushing = False
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\session.py:4488, in Session._flush(self, objects)
#    4485     transaction.commit()
#    4487 except:
# -> 4488     with util.safe_reraise():
#    4489         transaction.rollback(_capture_exception=True)
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:122, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     assert exc_value is not None
#     121     self._exc_info = None  # remove potential circular references
# --> 122     raise exc_value.with_traceback(exc_tb)
#     123 else:
#     124     self._exc_info = None  # remove potential circular references
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\session.py:4449, in Session._flush(self, objects)
#    4447 self._warn_on_events = True
#    4448 try:
# -> 4449     flush_context.execute()
#    4450 finally:
#    4451     self._warn_on_events = False
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\unitofwork.py:465, in UOWTransaction.execute(self)
#     463 else:
#     464     for rec in topological.sort(self.dependencies, postsort_actions):
# --> 465         rec.execute(self)
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\unitofwork.py:641, in SaveUpdateAll.execute(self, uow)
#     639 @util.preload_module("sqlalchemy.orm.persistence")
#     640 def execute(self, uow):
# --> 641     util.preloaded.orm_persistence.save_obj(
#     642         self.mapper,
#     643         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     644         uow,
#     645     )
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\persistence.py:94, in save_obj(base_mapper, states, uowtransaction, single)
#      82     update = _collect_update_commands(
#      83         uowtransaction, table, states_to_update
#      84     )
#      86     _emit_update_statements(
#      87         base_mapper,
#      88         uowtransaction,
#    (...)     91         update,
#      92     )
# ---> 94     _emit_insert_statements(
#      95         base_mapper,
#      96         uowtransaction,
#      97         mapper,
#      98         table,
#      99         insert,
#     100     )
#     102 _finalize_insert_update_commands(
#     103     base_mapper,
#     104     uowtransaction,
#    (...)    120     ),
#     121 )
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\persistence.py:1234, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1228     result = connection.execute(
#    1229         statement.values(value_params),
#    1230         params,
#    1231         execution_options=execution_options,
#    1232     )
#    1233 else:
# -> 1234     result = connection.execute(
#    1235         statement,
#    1236         params,
#    1237         execution_options=execution_options,
#    1238     )
#    1240 primary_key = result.inserted_primary_key
#    1241 if primary_key is None:
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1421, in Connection.execute(self, statement, parameters, execution_options)
#    1419     raise exc.ObjectNotExecutableError(statement) from err
#    1420 else:
# -> 1421     return meth(
#    1422         self,
#    1423         distilled_parameters,
#    1424         execution_options or NO_OPTIONS,
#    1425     )
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\sql\elements.py:526, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     524     if TYPE_CHECKING:
#     525         assert isinstance(self, Executable)
# --> 526     return connection._execute_clauseelement(
#     527         self, distilled_params, execution_options
#     528     )
#     529 else:
#     530     raise exc.ObjectNotExecutableError(self)
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1643, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1631 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1632     "compiled_cache", self.engine._compiled_cache
#    1633 )
#    1635 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1636     dialect=dialect,
#    1637     compiled_cache=compiled_cache,
#    (...)   1641     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1642 )
# -> 1643 ret = self._execute_context(
#    1644     dialect,
#    1645     dialect.execution_ctx_cls._init_compiled,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     execution_options,
#    1649     compiled_sql,
#    1650     distilled_parameters,
#    1651     elem,
#    1652     extracted_params,
#    1653     cache_hit=cache_hit,
#    1654 )
#    1655 if has_events:
#    1656     self.dispatch.after_execute(
#    1657         self,
#    1658         elem,
#    (...)   1662         ret,
#    1663     )
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1846     return self._exec_insertmany_context(dialect, context)
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985     result = context._setup_result_proxy()
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2365, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2363 elif should_wrap:
#    2364     assert sqlalchemy_exception is not None
# -> 2365     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2366 else:
#    2367     assert exc_info[1] is not None
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1967                 break
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#    1974     self.dispatch.after_cursor_execute(
#    1975         self,
#    1976         cursor,
#    (...)   1980         context.executemany,
#    1981     )
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\psycopg\cursor.py:117, in Cursor.execute(self, query, params, prepare, binary)
#     113         self._conn.wait(
#     114             self._execute_gen(query, params, prepare=prepare, binary=binary)
#     115         )
#     116 except e._NO_TRACEBACK as ex:
# --> 117     raise ex.with_traceback(None)
#     118 return self
#
# ProgrammingError: (psycopg.errors.UndefinedTable) relation "tenants" does not exist
# LINE 1: INSERT INTO tenants (full_name, email, phone, unit_number, l...
#                     ^
# [SQL: INSERT INTO tenants (full_name, email, phone, unit_number, lease_start_date, lease_end_date, notes) VALUES (%(full_name)s::VARCHAR, %(email)s::VARCHAR, %(phone)s::VARCHAR, %(unit_number)s::VARCHAR, %(lease_start_date)s::VARCHAR, %(lease_end_date)s::VARCHAR, %(notes)s::VARCHAR) RETURNING tenants.id, tenants.created_at, tenants.updated_at]
# [parameters: {'full_name': 'Bennet Dyani', 'email': 'dyani@gmail.com', 'phone': '+27809682354', 'unit_number': 'A1', 'lease_start_date': '2026-01-01', 'lease_end_date': '2026-12-31', 'notes': 'Prefers email communication'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
