# %%
#Tenant Management Notebook
import pandas as pd
from sqlalchemy import select
from src.database import SessionLocal
from src.models import Tenant

# %%
sample_tenants = pd.DataFrame(
    [
        {
            "full_name": "Bennet Dyani",
            "email": "bennet@gmail.com",
            "phone": "+27630632730",
            "unit_number": "A1",
            "lease_start_date": "2026-02-01",
            "lease_end_date": "2021-01-30",
            "notes": "Preferes email communication"

        },
        {
            "full_name": "Itumeleng Bedesho",
            "email": "itumeleng@gmail.com",
            "phone": "+27678238210",
            "unit_number": "B2",
            "lease_start_date": "2026-07-01",
            "lease_end_date": "2027-06-30",
            "notes": "Has recuring maintenance request"

        }
    ]
)

sample_tenants
# Out:
#            full_name                email         phone unit_number  \
# 0       Bennet Dyani     bennet@gmail.com  +27630632730          A1
# 1  Itumeleng Bedesho  itumeleng@gmail.com  +27678238210          B2
#
#   lease_start_date lease_end_date                             notes
# 0       2026-02-01     2021-01-30      Preferes email communication
# 1       2026-07-01     2027-06-30  Has recuring maintenance request

# %%
#Tenant helper
from sqlalchemy import select

def list_tenants():
    with SessionLocal() as session:
        return session.scalar(select(Tenant)).all()

def add_tenant(full_name, email=None, phone=None, unit_number=None, lease_start_date=None, lease_end_date=None, notes=None):
    tenant = Tenant(
        full_name=full_name,
        email=email,
        phone=phone,
        unit_number=unit_number,
        lease_start_date=lease_start_date,
        lease_end_date=lease_end_date,
        notes=notes
    )

    with SessionLocal() as session:
        session.add(tenant)
        session.commit()
        session.refresh(tenant)

    return tenant

# %%
#Tenant lookup

def get_tenant_by_id(tenant_id):
    with SessionLocal() as session:
        return session.get(Tenant, tenant_id)

def get_tenant_by_email(email):
    with SessionLocal() as session:
        return session.scalar(select(Tenant).where(Tenant.email == email))

def get_tenant_by_phone(phone):
    with SessionLocal() as session:
        return session.scalar(select(Tenant).where(Tenant.phone == phone))

def get_tenant_by_unit(unit_number):
    with SessionLocal() as session:
        return session.scalar(select(Tenant).where(Tenant.unit_number == unit_number))

# %%
#Basic tenant Q&A

def tenant_qa(query, tenant_id=None, email=None, phone= None, unit_number=None):
    """
    Sample tenant Q&A function:
    Find a tenant and answer basic questions about them.
    """
    tenant = None
    if tenant_id:
        tenant = get_tenant_by_id(tenant_id)
    elif email:
        tenant = get_tenant_by_email(email)
    elif phone:
        tenant = get_tenant_by_phone(phone)
    elif unit_number:
        tenant = get_tenant_by_unit(unit_number)

    if not tenant:
        return "Tenant not found"

    query_lower = query.lower()

    if "name" in query_lower:
        return f"Tenant name: {tenant.full_name}"
    elif "email" in query_lower:
        return f"Email: {tenant.email}"
    elif "phone" in query_lower:
        return f"Phone: {tenant.phone}"
    elif "unit" in query_lower:
        return f"Unit: {tenant.unit_number}"
    elif "lease" in query_lower:
        return f"Lease: {tenant.lease_start_date} to {tenant.lease_end_date}"
    elif "notes" in query_lower:
        return f"Notes: {tenant.notes}"
    else:
        return f"Tenant info: {tenant.full_name}, Unit {tenant.unit_number}, Email: {tenant.email}"

# %%
# Insert sample tenants
tenant1 = add_tenant(
    full_name="Bennet Dyani",
    email="dyani@gmail.com",
    phone="+27809682354",
    unit_number="A1",
    lease_start_date="2026-01-01",
    lease_end_date="2026-12-31",
    notes="Prefers email communication",
)

tenant2 = add_tenant(
    full_name="Itumeleng Bedesho",
    email="bedesho@gmailcom",
    phone="+27633981147",
    unit_number="B3",
    lease_start_date="2026-02-01",
    lease_end_date="2027-01-31",
    notes="Has recurring maintenance request history",
)

print("Sample tenants added:")
print(f"Tenant 1: {tenant1.full_name} (ID: {tenant1.id})")
print(f"Tenant 2: {tenant2.full_name} (ID: {tenant2.id})")

# Test Q&A
print("\n--- Testing Q&A ---")
print(tenant_qa("What is the tenant's name?", tenant_id=tenant1.id))
print(tenant_qa("What's their email?", email="brian@example.com"))
print(tenant_qa("What unit?", phone="+254700000001"))
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\engine\base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 try:
# --> 144     self._dbapi_connection = engine.raw_connection()
#     145 except dialect.loaded_dbapi.Error as err:
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3319, in Engine.raw_connection(self)
#    3298 """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300 The returned object is a proxied version of the DBAPI
#    (...)   3317
#    3318 """
# -> 3319 return self.pool.connect()
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
#     442
#     443 The connection is instrumented such that when its
#    (...)    446
#     447 """
# --> 448 return _ConnectionFairy._checkout(self)
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\pool\base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1271 if not fairy:
# -> 1272     fairy = _ConnectionRecord.checkout(pool)
#    1274     if threadconns is not None:
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:178, in QueuePool._do_get(self)
#     177 except:
# --> 178     with util.safe_reraise():
#     179         self._dec_overflow()
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:122, in safe_reraise.__exit__(self, type_, value, traceback)
#     121     self._exc_info = None  # remove potential circular references
# --> 122     raise exc_value.with_traceback(exc_tb)
#     123 else:
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:176, in QueuePool._do_get(self)
#     175 try:
# --> 176     return self._create_connection()
#     177 except:
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\pool\base.py:389, in Pool._create_connection(self)
#     387 """Called by subclasses to create a new ConnectionRecord."""
# --> 389 return _ConnectionRecord(self)
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:122, in safe_reraise.__exit__(self, type_, value, traceback)
#     121     self._exc_info = None  # remove potential circular references
# --> 122     raise exc_value.with_traceback(exc_tb)
#     123 else:
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\engine\create.py:667, in create_engine.<locals>.connect(connection_record)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\engine\default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\psycopg\connection.py:130, in Connection.connect(cls, conninfo, autocommit, prepare_threshold, context, row_factory, cursor_factory, **kwargs)
#     129     new_ex = type(last_ex)("\n".join(lines), pgconn=last_ex.pgconn)
# --> 130     raise new_ex.with_traceback(None)
#     132 if (
#     133     capabilities.has_used_gssapi()
#     134     and rv.pgconn.used_gssapi
#     135     and (not gssapi_requested(params))
#     136 ):
#
# OperationalError: connection failed: connection to server at "127.0.0.1", port 5432 failed: FATAL:  password authentication failed for user "postgres"
# Multiple connection attempts failed. All failures were:
# - host: 'localhost', port: 5432, hostaddr: '::1': connection failed: connection to server at "::1", port 5432 failed: FATAL:  password authentication failed for user "postgres"
# - host: 'localhost', port: 5432, hostaddr: '127.0.0.1': connection failed: connection to server at "127.0.0.1", port 5432 failed: FATAL:  password authentication failed for user "postgres"
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Insert sample tenants
# ----> 2 tenant1 = add_tenant(
#       3     full_name="Bennet Dyani",
#       4     email="dyani@gmail.com",
#       5     phone="+27809682354",
#
# Cell In[6], line 21, in add_tenant(full_name, email, phone, unit_number, lease_start_date, lease_end_date, notes)
#      17     )
#      18
#      19     with SessionLocal() as session:
#      20         session.add(tenant)
# ---> 21         session.commit()
#      22         session.refresh(tenant)
#      23
#      24     return tenant
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\session.py:2035, in Session.commit(self)
#    2032 if trans is None:
#    2033     trans = self._autobegin_t()
# -> 2035 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     135 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#     139     raise
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\session.py:1316, in SessionTransaction.commit(self, _to_root)
#    1314 if self._state is not SessionTransactionState.PREPARED:
#    1315     with self._expect_state(SessionTransactionState.PREPARED):
# -> 1316         self._prepare_impl()
#    1318 if self._parent is None or self.nested:
#    1319     for conn, trans, should_commit, autoclose in set(
#    1320         self._connections.values()
#    1321     ):
#
# File <string>:2, in _prepare_impl(self)
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     135 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#     139     raise
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\session.py:1290, in SessionTransaction._prepare_impl(self)
#    1288     if self.session._is_clean():
#    1289         break
# -> 1290     self.session.flush()
#    1291 else:
#    1292     raise exc.FlushError(
#    1293         "Over 100 subsequent flushes have occurred within "
#    1294         "session.commit() - is an after_flush() hook "
#    1295         "creating new objects?"
#    1296     )
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\session.py:4353, in Session.flush(self, objects)
#    4351 try:
#    4352     self._flushing = True
# -> 4353     self._flush(objects)
#    4354 finally:
#    4355     self._flushing = False
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\session.py:4488, in Session._flush(self, objects)
#    4485     transaction.commit()
#    4487 except:
# -> 4488     with util.safe_reraise():
#    4489         transaction.rollback(_capture_exception=True)
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:122, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     assert exc_value is not None
#     121     self._exc_info = None  # remove potential circular references
# --> 122     raise exc_value.with_traceback(exc_tb)
#     123 else:
#     124     self._exc_info = None  # remove potential circular references
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\session.py:4449, in Session._flush(self, objects)
#    4447 self._warn_on_events = True
#    4448 try:
# -> 4449     flush_context.execute()
#    4450 finally:
#    4451     self._warn_on_events = False
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\unitofwork.py:465, in UOWTransaction.execute(self)
#     463 else:
#     464     for rec in topological.sort(self.dependencies, postsort_actions):
# --> 465         rec.execute(self)
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\unitofwork.py:641, in SaveUpdateAll.execute(self, uow)
#     639 @util.preload_module("sqlalchemy.orm.persistence")
#     640 def execute(self, uow):
# --> 641     util.preloaded.orm_persistence.save_obj(
#     642         self.mapper,
#     643         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     644         uow,
#     645     )
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\persistence.py:69, in save_obj(base_mapper, states, uowtransaction, single)
#      58 states_to_update = []
#      59 states_to_insert = []
#      61 for (
#      62     state,
#      63     dict_,
#      64     mapper,
#      65     connection,
#      66     has_identity,
#      67     row_switch,
#      68     update_version_id,
# ---> 69 ) in _organize_states_for_save(base_mapper, states, uowtransaction):
#      70     if has_identity or row_switch:
#      71         states_to_update.append(
#      72             (state, dict_, mapper, connection, update_version_id)
#      73         )
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\persistence.py:224, in _organize_states_for_save(base_mapper, states, uowtransaction)
#     212 def _organize_states_for_save(base_mapper, states, uowtransaction):
#     213     """Make an initial pass across a set of states for INSERT or
#     214     UPDATE.
#     215
#    (...)    221
#     222     """
# --> 224     for state, dict_, mapper, connection in _connections_for_states(
#     225         base_mapper, uowtransaction, states
#     226     ):
#     227         has_identity = bool(state.key)
#     229         instance_key = state.key or mapper._identity_key_from_state(state)
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\persistence.py:1760, in _connections_for_states(base_mapper, uowtransaction, states)
#    1758     connection_callable = uowtransaction.session.connection_callable
#    1759 else:
# -> 1760     connection = uowtransaction.transaction.connection(base_mapper)
#    1761     connection_callable = None
#    1763 for state in _sort_states(base_mapper, states):
#
# File <string>:2, in connection(self, bindkey, execution_options, **kwargs)
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     135 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#     139     raise
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\session.py:1041, in SessionTransaction.connection(self, bindkey, execution_options, **kwargs)
#    1031 @_StateChange.declare_states(
#    1032     (SessionTransactionState.ACTIVE,), _StateChangeStates.NO_CHANGE
#    1033 )
#    (...)   1038     **kwargs: Any,
#    1039 ) -> Connection:
#    1040     bind = self.session.get_bind(bindkey, **kwargs)
# -> 1041     return self._connection_for_bind(bind, execution_options)
#
# File <string>:2, in _connection_for_bind(self, bind, execution_options)
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     135 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#     139     raise
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\session.py:1177, in SessionTransaction._connection_for_bind(self, bind, execution_options)
#    1175 try:
#    1176     if self._parent:
# -> 1177         conn = self._parent._connection_for_bind(
#    1178             bind, execution_options
#    1179         )
#    1180         if not self.nested:
#    1181             return conn
#
# File <string>:2, in _connection_for_bind(self, bind, execution_options)
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     135 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#     139     raise
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\orm\session.py:1191, in SessionTransaction._connection_for_bind(self, bind, execution_options)
#    1186             raise sa_exc.InvalidRequestError(
#    1187                 "Session already has a Connection associated "
#    1188                 "for the given Connection's Engine"
#    1189             )
#    1190     else:
# -> 1191         conn = bind.connect()
#    1192         local_connect = True
#    1194 try:
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3295, in Engine.connect(self)
#    3272 def connect(self) -> Connection:
#    3273     """Return a new :class:`_engine.Connection` object.
#    3274
#    3275     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)   3292
#    3293     """
# -> 3295     return self._connection_cls(self)
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144         self._dbapi_connection = engine.raw_connection()
#     145     except dialect.loaded_dbapi.Error as err:
# --> 146         Connection._handle_dbapi_exception_noconnection(
#     147             err, dialect, engine
#     148         )
#     149         raise
#     150 else:
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2450, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2448 elif should_wrap:
#    2449     assert sqlalchemy_exception is not None
# -> 2450     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2451 else:
#    2452     assert exc_info[1] is not None
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\engine\base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 if connection is None:
#     143     try:
# --> 144         self._dbapi_connection = engine.raw_connection()
#     145     except dialect.loaded_dbapi.Error as err:
#     146         Connection._handle_dbapi_exception_noconnection(
#     147             err, dialect, engine
#     148         )
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3319, in Engine.raw_connection(self)
#    3297 def raw_connection(self) -> PoolProxiedConnection:
#    3298     """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300     The returned object is a proxied version of the DBAPI
#    (...)   3317
#    3318     """
# -> 3319     return self.pool.connect()
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     440 def connect(self) -> PoolProxiedConnection:
#     441     """Return a DBAPI connection from the pool.
#     442
#     443     The connection is instrumented such that when its
#    (...)    446
#     447     """
# --> 448     return _ConnectionFairy._checkout(self)
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\pool\base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1264 @classmethod
#    1265 def _checkout(
#    1266     cls,
#    (...)   1269     fairy: Optional[_ConnectionFairy] = None,
#    1270 ) -> _ConnectionFairy:
#    1271     if not fairy:
# -> 1272         fairy = _ConnectionRecord.checkout(pool)
#    1274         if threadconns is not None:
#    1275             threadconns.current = weakref.ref(fairy)
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:178, in QueuePool._do_get(self)
#     176     return self._create_connection()
#     177 except:
# --> 178     with util.safe_reraise():
#     179         self._dec_overflow()
#     180     raise
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:122, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     assert exc_value is not None
#     121     self._exc_info = None  # remove potential circular references
# --> 122     raise exc_value.with_traceback(exc_tb)
#     123 else:
#     124     self._exc_info = None  # remove potential circular references
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:176, in QueuePool._do_get(self)
#     174 if self._inc_overflow():
#     175     try:
# --> 176         return self._create_connection()
#     177     except:
#     178         with util.safe_reraise():
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\pool\base.py:389, in Pool._create_connection(self)
#     386 def _create_connection(self) -> ConnectionPoolEntry:
#     387     """Called by subclasses to create a new ConnectionRecord."""
# --> 389     return _ConnectionRecord(self)
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:122, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     assert exc_value is not None
#     121     self._exc_info = None  # remove potential circular references
# --> 122     raise exc_value.with_traceback(exc_tb)
#     123 else:
#     124     self._exc_info = None  # remove potential circular references
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\engine\create.py:667, in create_engine.<locals>.connect(connection_record)
#     665     return dialect.connect(*mutable_cargs, **mutable_cparams)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\sqlalchemy\engine\default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File C:\agentic\Property-Rental-Management-System\.venv\Lib\site-packages\psycopg\connection.py:130, in Connection.connect(cls, conninfo, autocommit, prepare_threshold, context, row_factory, cursor_factory, **kwargs)
#     128     lines.extend((f"- {descr}: {error}" for error, descr in conn_errors))
#     129     new_ex = type(last_ex)("\n".join(lines), pgconn=last_ex.pgconn)
# --> 130     raise new_ex.with_traceback(None)
#     132 if (
#     133     capabilities.has_used_gssapi()
#     134     and rv.pgconn.used_gssapi
#     135     and (not gssapi_requested(params))
#     136 ):
#     137     warnings.warn(
#     138         "the connection was obtained using the GSSAPI relying on the 'gssencmode=prefer' libpq default. The value for this default might be 'disable' instead, in certain psycopg[binary] implementations. If you wish to interact with the GSSAPI reliably please set the 'gssencmode' parameter in the connection string or the 'PGGSSENCMODE' environment variable to 'prefer' or 'require'",
#     139         RuntimeWarning,
#     140     )
#
# OperationalError: (psycopg.OperationalError) connection failed: connection to server at "127.0.0.1", port 5432 failed: FATAL:  password authentication failed for user "postgres"
# Multiple connection attempts failed. All failures were:
# - host: 'localhost', port: 5432, hostaddr: '::1': connection failed: connection to server at "::1", port 5432 failed: FATAL:  password authentication failed for user "postgres"
# - host: 'localhost', port: 5432, hostaddr: '127.0.0.1': connection failed: connection to server at "127.0.0.1", port 5432 failed: FATAL:  password authentication failed for user "postgres"
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
